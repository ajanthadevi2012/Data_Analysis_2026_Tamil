# %%
def even_num(num):
    evens = []
    for n in num:
        if n% 2==0:
            evens.append(n)
    return evens

# %%
a = [2,3,4,5,6,7,8,9,10]
resu = even_num(a)
print("only the even: ",resu)
# Out:
# only the even:  [2, 4, 6, 8, 10]

# %%
result_new = list(filter(lambda x:x%2==0, a))
result_new
# Out:
# [2, 4, 6, 8, 10]

# %%
b = [3,-6,7,-2,4,5,-8]
result_new_1 = list(filter(lambda x:x>0, b))
result_new_1
# Out:
# [3, 7, 4, 5]

# %%
b = [3,-6,7,-2,4,5,-8]
result_new_1 = list(filter(lambda x:x<0, b))
result_new_1
# Out:
# [-6, -2, -8]

# %%
a = [2,3,4,5,6,7,8,9,10]
result_new_2 = list(map(lambda x:x*2, a))
result_new_2
# Out:
# [4, 6, 8, 10, 12, 14, 16, 18, 20]

# %%
from functools import reduce
a
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
res = reduce(lambda x, sum: x+sum, a)
res
# Out:
# 54
