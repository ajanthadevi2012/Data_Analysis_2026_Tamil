# %%
def divd(a,b):
    result = a/b
    print(result)

# %%
divd(10,4)
# Out:
# 2.5

# %%
divd(10,5)
# Out:
# 2.0

# %%
divd(10,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 divd(10,0)
#
# Cell In[1], line 2, in divd(a, b)
#       1 def divd(a,b):
# ----> 2     result = a/b
#       3     print(result)
#
# ZeroDivisionError: division by zero

# %%
def divd_1(a,b):
    result = a/b
    print(reslut)

# %%
divd_1(10,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 divd_1(10,5)
#
# Cell In[5], line 3, in divd_1(a, b)
#       1 def divd_1(a,b):
#       2     result = a/b
# ----> 3     print(reslut)
#
# NameError: name 'reslut' is not defined

# %%
divd_1(10,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 divd_1(10,0)
#
# Cell In[5], line 2, in divd_1(a, b)
#       1 def divd_1(a,b):
# ----> 2     result = a/b
#       3     print(reslut)
#
# ZeroDivisionError: division by zero

# %%
def divd_1(a,b):
    try:
        result = a/b
        print(reslut)
    except Exception as e:
        print(e)

# %%
divd_1(10,5)
# Out:
# name 'reslut' is not defined

# %%
divd_1(10,0)
# Out:
# division by zero

# %%
def divd_1(a,b):
    try:
        result = a/b
        print(reslut)
    except NameError:
        print("check the variable u have entered")
    except ZeroDivisionError:
        print("number dividing by zero is not acceptable")

# %%
divd_1(10,4)
# Out:
# check the variable u have entered

# %%
divd_1(10,0)
# Out:
# number dividing by zero is not acceptable

# %%
def divd_1(a,b):
    try:
        result = a/b
        print(reslut)
    
    except (NameError,ZeroDivisionError):
        print("check the variable u have entered")
        print("number dividing by zero is not acceptable")

# %%
divd_1(10,0)
# Out:
# check the variable u have entered
# number dividing by zero is not acceptable

# %%
divd_1(10,3)
# Out:
# check the variable u have entered
# number dividing by zero is not acceptable

# %%
def divd_1(a,b):
    try:
        result = a/b
        print(reslut)
    except NameError:
        print("check the variable u have entered")
    except ZeroDivisionError:
        print("number dividing by zero is not acceptable")
    finally:
        print("all is done")

# %%
divd_1(10,3)
# Out:
# check the variable u have entered
# all is done

# %%
divd_1(10,0)
# Out:
# number dividing by zero is not acceptable
# all is done
