# %% [markdown]
# # Python Input, Output and Import
#
# This class focuses on two built-in functions **`print()`** and **`input()`** to perform I/O task in Python. Also, you will learn to import modules and use them in your program.
#
#
# Some of the functions like **`print()`** and **`input()`** are widely used for standard input and output operations respectively. Let us see the output section first.

# %% [markdown]
# ## 1. Python Output Using `print()` function
#
#
# An example of its use is given below.

# %%
print("askdhkjashd kjasdkjaskjd askjdnasnd asdbasbd")
# Out:
# askdhkjashd kjasdkjaskjd askjdnasnd asdbasbd

# %%
a = 90
print(a)
# Out:
# 90

# %%
print("the value of a is: ", a)
# Out:
# the value of a is:  90

# %%
a=12
b=34
c=56
print(a,b,c)
# Out:
# 12 34 56

# %%
print("the value of a is ", a, " the value of b is :", b)
# Out:
# the value of a is  12  the value of b is : 34

# %% [markdown]
# ## Output formatting
#
# Sometimes we would like to format our output to make it look attractive. This can be done by using the **`str.format()`** method. This method is visible to any string object.

# %%
print("the value of a is {} and b is {}".format(a,b))   # {}place holder
# Out:
# the value of a is 12 and b is 34

# %%
print("the value of a is {} and b is {}".format("mango","banana"))
# Out:
# the value of a is mango and b is banana

# %%
print("the value of a is {} and b is {}, {}".format("mango","banana"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print("the value of a is {} and b is {}, {}".format("mango","banana"))
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %%
print("the value of a is {0} and b is {1}, {1}".format("mango","banana"))
# Out:
# the value of a is mango and b is banana, banana

# %%
print("the value of a is {0} and b is {1}, {0}".format("mango","banana"))
# Out:
# the value of a is mango and b is banana, mango

# %%
# keyword argu
print("the value of a is {b} and b is {a}, {a}".format(a = "mango", b  = "banana"))
# Out:
# the value of a is banana and b is mango, mango

# %% [markdown]
# ## 2. Python Input Using `input()` function
#
# Up until now, our programs were static. The value of variables was defined or hard coded into the source code.
#
# To allow flexibility, we might want to take the input from the user. In Python, we have a built-in function **`input()`** to accept user input.
#
# **Syntax**:
#
# ```python
# input([prompt])
# ```
#
# where **`prompt`** is the string we wish to display on the screen. It is optional.

# %%
a  =  input("enter a number")
# Out:
# enter a number 4

# %%
a
# Out:
# '4'

# %%
a = int(input("enter the number"))
a
# Out:
# enter the number 67
# 67

# %%
b = float(input("enter the price of the product"))
b
# Out:
# enter the price of the product 99.99
# 99.99

# %%
type(b)
# Out:
# float

# %%
a,b,c = 4,5.6,"ajan"

# %%
a
# Out:
# 4

# %%
b
# Out:
# 5.6

# %%
c
# Out:
# 'ajan'

# %%
name, age, price = input("enter ur name, age, and puchased price")
# Out:
# enter ur name, age, and puchased price ajantha 88 78.99
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 name, age, price = input("enter ur name, age, and puchased price")
#
# ValueError: too many values to unpack (expected 3)

# %%
name, age, price = input("enter ur name, age, and puchased price")
# Out:
# enter ur name, age, and puchased price ajantha,99,34,50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 name, age, price = input("enter ur name, age, and puchased price")
#
# ValueError: too many values to unpack (expected 3)

# %%
name, age, price = input("enter ur name, age, and puchased price")
# Out:
# enter ur name, age, and puchased price ajantha,99,34.50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 name, age, price = input("enter ur name, age, and puchased price")
#
# ValueError: too many values to unpack (expected 3)

# %%
name, age, price = input("enter ur name, age, and puchased price").split() # split => " "
# Out:
# enter ur name, age, and puchased price ajantha 88 76.99

# %%
name
# Out:
# 'ajantha'

# %%
age
# Out:
# '88'

# %%
price
# Out:
# '76.99'

# %%
name, age, price = input("enter ur name, age, and puchased price").split()
# Out:
# enter ur name, age, and puchased price ajantha devi 95 75.99
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 name, age, price = input("enter ur name, age, and puchased price").split()
#
# ValueError: too many values to unpack (expected 3)

# %%
name, age, price = input("enter ur name, age, and puchased price(separ with comma)").split(",") # split => " ,"
# Out:
# enter ur name, age, and puchased price(separ with comma) ajantha devi,88, 87.99

# %% [markdown]
# ## 3. Python `Import` function
#
# When our program grows bigger, it is a good idea to break it into different modules.
#
#
# Definitions inside a module can be imported to another module or the interactive interpreter in Python. We use the **`import`** keyword to do this.
#
# For example, we can import the **`math`** module by typing the following line:
#
# ```python
# >import math
# ```

# %%
import maths
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import maths
#
# ModuleNotFoundError: No module named 'maths'

# %%
import math

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.pi
# Out:
# 3.141592653589793
